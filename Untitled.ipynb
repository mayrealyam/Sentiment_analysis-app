# %%
import numpy as np

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Maryam
# [nltk_data]     Yusuf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
word = ["This", "is", "lovely", "and", "love", "it"]
N =15000
word1= (word + N * [" 0"])[:N]

# %%
print(word)
print(word1)
print(len(word1))
# Out:
# ['This', 'is', 'lovely', 'and', 'love', 'it']
# ...

# %%
a = np.array([1,1,1])
b = np.pad(a, (0, 1588-len(a)))

# %%
len(b)
# Out:
# 1588
